# %% [markdown]
# <a href="https://colab.research.google.com/github/nafeeur/cuny_data_analytics/blob/main/SQL/Unit5/Unit_5_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Nafeeur Rahman***
#
# *Lesson 5: Joins and Unions*
#
# # ***(1)Join the film to the film_actor table.***
#
# ##SELECT * FROM film_actor
# ##FULL JOIN film ON film_actor.film_id = film.film_id;
#
# ![13B5538C-2668-48CB-8D4E-E49076C54B10.jpeg](data:image/jpeg;base64,...)
#
# ![07D6771D-6FE3-4F1A-A04E-89B20E5F2EE6.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ##SELECT film.title, film.length, film.description, film.rating
# ##FROM film_actor INNER JOIN film ON film_actor.film_id = film.film_id;
#
# ![A02B5CBE-5ABF-40CE-98E2-23629020521F.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### ***(2)Join the actor table to the film_actor table.***
#
# ##SELECT film_actor.actor_id, film_actor.last_update, film_actor.film_id, actor.first_name, actor.last_name
# ##FROM film_actor INNER JOIN actor ON film_actor.actor_id = actor.actor_id;
# ![6D74B218-7C69-480F-A2B7-39A29A906EB6.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## ***(3)Try to join the actor, film_actor, and film table together (3 joins!)***
#
# ##SELECT
# ##film.film_id, film.title, film.release_year, film.description, film_actor.actor_id, actor.last_name, actor.first_name, actor.actor_id
# ##FROM film
# ##JOIN film_actor
# ##ON film.film_id = film_actor.film_id
# ##JOIN actor
# ##ON film_actor.actor_id = actor.actor_id;
#
# ![393AE06C-B070-484D-AF80-F5300A0078D8.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## ***(4) With the attached data set (Student_data and Student_marks ) answer the following questions :***
#
# ## ***Students with the highest mark in Unit 4***
#
# ![B16ABEC9-8867-4D6B-9719-E707C69C6EEF.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![EC191BE3-2187-4D31-A972-3882F87356E1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # ***Find students scored between 89 and 100 unit4***

# %% [markdown]
# ![122E364E-02AB-498B-8AAA-DA11A13A69C8.jpeg](data:image/jpeg;base64,...)
